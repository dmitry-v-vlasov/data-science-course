# %%
import pandas as pd

from prophet import Prophet

url = 'https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv'

df = pd.read_csv(url)

df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
model = Prophet()
model.fit(df)
# Out:
# 14:09:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:09:08 - cmdstanpy - INFO - Chain [1] done processing

# %%
future_df = model.make_future_dataframe(periods=365)
future_df.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast_df = model.predict(future_df)
forecast_df[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.205874    7.472888    8.928991
# 3266 2017-01-16  8.530900    7.762722    9.255886
# 3267 2017-01-17  8.318295    7.552242    9.031613
# 3268 2017-01-18  8.150892    7.324841    8.838215
# 3269 2017-01-19  8.162855    7.427748    8.892140

# %%
fig = model.plot(forecast_df)

# %%
fig = model.plot_components(forecast_df)
