# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import model_selection
from sklearn import linear_model
from sklearn import tree
from sklearn import ensemble
from sklearn import metrics

# %%
data_wine = pd.read_csv('data/wineQualityReds.csv')
data_wine.head(10)
# Out:
#    Unnamed: 0  fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# 0           1            7.4              0.70         0.00             1.9
# 1           2            7.8              0.88         0.00             2.6
# 2           3            7.8              0.76         0.04             2.3
# 3           4           11.2              0.28         0.56             1.9
# 4           5            7.4              0.70         0.00             1.9
# 5           6            7.4              0.66         0.00             1.8
# 6           7            7.9              0.60         0.06             1.6
# 7           8            7.3              0.65         0.00             1.2
# 8           9            7.8              0.58         0.02             2.0
# 9          10            7.5              0.50         0.36             6.1
#
#    chlorides  free.sulfur.dioxide  total.sulfur.dioxide  density    pH  \
# ...

# %%
data = data_wine.copy(deep=True)

data.drop(['Unnamed: 0'], axis=1, inplace=True)

data['quality'] = data['quality'].apply(lambda q: 1 if q >=6 else 0)
data.head(10)
# Out:
#    fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# ...

# %%
X = data.drop(['quality'], axis=1)
y = data['quality']

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.3, random_state=42)
display(X_train.shape)
display(X_test.shape)
# Out:
# (1119, 11)
# (480, 11)

# %%
model = linear_model.LogisticRegression(random_state=42)
model.fit(X_train, y_train)

y_test_pred = model.predict(X_test)

display(metrics.f1_score(y_test, y_test_pred))
# Out:
# /home/sorcerer/.conda/envs/data-science/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7514231499051234

# %%
model = tree.DecisionTreeClassifier(max_depth=10, random_state=42)
model.fit(X_train, y_train)

y_test_pred = model.predict(X_test)

display(metrics.f1_score(y_test, y_test_pred))
# Out:
# 0.7927927927927927

# %%
base_model = tree.DecisionTreeClassifier(max_depth=10, random_state=42)
model = ensemble.BaggingClassifier(base_estimator=base_model, n_estimators=1500, random_state=42)
model.fit(X_train, y_train)

y_test_pred = model.predict(X_test)

display(metrics.f1_score(y_test, y_test_pred))
# Out:
# 0.8181818181818181
